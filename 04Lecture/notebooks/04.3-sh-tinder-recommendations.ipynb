# %%
import pandas as pd

# %%
tinder_data = pd.read_csv("../data/tinder_data_prepared.csv")

# %%
# check shape
tinder_data.shape
# Out:
# (1321, 58)

# %%
# check info
tinder_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321 entries, 0 to 1320
# Data columns (total 58 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   user_id                                1321 non-null   object
#  1   age                                    1321 non-null   int64
#  2   sex                                    1321 non-null   int64
#  3   height                                 1321 non-null   float64
#  4   education_level                        1321 non-null   float64
#  5   dropped_out                            1321 non-null   int64
#  6   drinks_desperately                     1321 non-null   bool
#  7   drinks_not at all                      1321 non-null   bool
#  8   drinks_often                           1321 non-null   bool
#  9   drinks_rarely                          1321 non-null   bool
#  10  drinks_socially                        1321 non-null   bool
#  11  drinks_very often                      1321 non-null   bool
#  12  drugs_never                            1321 non-null   bool
#  13  drugs_often                            1321 non-null   bool
#  14  drugs_sometimes                        1321 non-null   bool
#  15  job_artistic / musical / writer        1321 non-null   bool
#  16  job_banking / financial / real estate  1321 non-null   bool
#  17  job_clerical / administrative          1321 non-null   bool
#  18  job_computer / hardware / software     1321 non-null   bool
#  19  job_construction / craftsmanship       1321 non-null   bool
#  20  job_education / academia               1321 non-null   bool
#  21  job_entertainment / media              1321 non-null   bool
#  22  job_executive / management             1321 non-null   bool
#  23  job_hospitality / travel               1321 non-null   bool
#  24  job_law / legal services               1321 non-null   bool
#  25  job_medicine / health                  1321 non-null   bool
#  26  job_military                           1321 non-null   bool
#  27  job_other                              1321 non-null   bool
#  28  job_political / government             1321 non-null   bool
#  29  job_rather not say                     1321 non-null   bool
#  30  job_retired                            1321 non-null   bool
#  31  job_sales / marketing / biz dev        1321 non-null   bool
#  32  job_science / tech / engineering       1321 non-null   bool
#  33  job_student                            1321 non-null   bool
#  34  job_transportation                     1321 non-null   bool
#  35  job_unemployed                         1321 non-null   bool
#  36  smokes_no                              1321 non-null   bool
#  37  smokes_sometimes                       1321 non-null   bool
#  38  smokes_trying to quit                  1321 non-null   bool
#  39  smokes_when drinking                   1321 non-null   bool
#  40  smokes_yes                             1321 non-null   bool
#  41  body_profile_a little extra            1321 non-null   bool
#  42  body_profile_athletic                  1321 non-null   bool
#  43  body_profile_average                   1321 non-null   bool
#  44  body_profile_curvy                     1321 non-null   bool
#  45  body_profile_fit                       1321 non-null   bool
#  46  body_profile_full figured              1321 non-null   bool
#  47  body_profile_jacked                    1321 non-null   bool
#  48  body_profile_overweight                1321 non-null   bool
#  49  body_profile_rather not say            1321 non-null   bool
#  50  body_profile_skinny                    1321 non-null   bool
#  51  body_profile_thin                      1321 non-null   bool
#  52  body_profile_used up                   1321 non-null   bool
#  53  new_languages_interested               1321 non-null   bool
#  54  new_languages_not interested           1321 non-null   bool
#  55  new_languages_somewhat interested      1321 non-null   bool
#  56  likes_dog                              1321 non-null   int64
#  57  likes_cats                             1321 non-null   int64
# dtypes: bool(50), float64(2), int64(5), object(1)
# memory usage: 147.2+ KB

# %%
tinder_data.head()
# Out:
#         user_id  age  sex  height  education_level  dropped_out  \
# 0  fffe31003000   28    1    62.0              4.0            0
# 1  fffe31003200   24    0    65.0              3.0            0
# 2  fffe31003300   29    1    73.0              3.0            0
# 3  fffe31003400   33    0    65.0              4.0            0
# 4  fffe31003500   39    0    65.0              4.0            0
#
#    drinks_desperately  drinks_not at all  drinks_often  drinks_rarely  ...  \
# 0               False              False         False          False  ...
# 1               False              False         False          False  ...
# 2               False              False         False          False  ...
# 3               False              False         False          False  ...
# 4               False              False          True          False  ...
#
#    body_profile_overweight  body_profile_rather not say  body_profile_skinny  \
# 0                    False                        False                False
# 1                    False                        False                False
# 2                    False                        False                False
# 3                    False                        False                False
# 4                    False                        False                False
#
#    body_profile_thin  body_profile_used up  new_languages_interested  \
# 0              False                  True                     False
# 1              False                 False                      True
# 2              False                 False                     False
# 3              False                 False                     False
# 4              False                 False                     False
#
#    new_languages_not interested  new_languages_somewhat interested  likes_dog  \
# 0                          True                              False          1
# 1                         False                              False          1
# 2                          True                              False          1
# 3                          True                              False          0
# 4                          True                              False          1
#
#    likes_cats
# 0           1
# 1           1
# 2           1
# 3           0
# 4           0
#
# [5 rows x 58 columns]

# %%
# set index
tinder_data = tinder_data.set_index("user_id")

# %%
tinder_data.head()
# Out:
#               age  sex  height  education_level  dropped_out  \
# user_id
# fffe31003000   28    1    62.0              4.0            0
# fffe31003200   24    0    65.0              3.0            0
# fffe31003300   29    1    73.0              3.0            0
# fffe31003400   33    0    65.0              4.0            0
# fffe31003500   39    0    65.0              4.0            0
#
#               drinks_desperately  drinks_not at all  drinks_often  \
# user_id
# fffe31003000               False              False         False
# fffe31003200               False              False         False
# fffe31003300               False              False         False
# fffe31003400               False              False         False
# fffe31003500               False              False          True
#
#               drinks_rarely  drinks_socially  ...  body_profile_overweight  \
# user_id                                       ...
# fffe31003000          False            False  ...                    False
# fffe31003200          False             True  ...                    False
# fffe31003300          False             True  ...                    False
# fffe31003400          False             True  ...                    False
# fffe31003500          False            False  ...                    False
#
#               body_profile_rather not say  body_profile_skinny  \
# user_id
# fffe31003000                        False                False
# fffe31003200                        False                False
# fffe31003300                        False                False
# fffe31003400                        False                False
# fffe31003500                        False                False
#
#               body_profile_thin  body_profile_used up  \
# user_id
# fffe31003000              False                  True
# fffe31003200              False                 False
# fffe31003300              False                 False
# fffe31003400              False                 False
# fffe31003500              False                 False
#
#               new_languages_interested  new_languages_not interested  \
# user_id
# fffe31003000                     False                          True
# fffe31003200                      True                         False
# fffe31003300                     False                          True
# fffe31003400                     False                          True
# fffe31003500                     False                          True
#
#               new_languages_somewhat interested  likes_dog  likes_cats
# user_id
# fffe31003000                              False          1           1
# fffe31003200                              False          1           1
# fffe31003300                              False          1           1
# fffe31003400                              False          0           0
# fffe31003500                              False          1           0
#
# [5 rows x 57 columns]

# %%
from sklearn.decomposition import TruncatedSVD 

# Apply SVD to the training data
svd = TruncatedSVD(n_components=20) 
# this is a matrix of all the profiles of the opposite gender
tinder_profiles_matrix = svd.fit_transform(tinder_data)

tinder_profiles_matrix
# Out:
# array([[ 6.81246999e+01,  1.84406016e+00, -3.91469382e-01, ...,
#         -8.54875364e-02, -1.03044108e-01,  2.65165081e-01],
#        [ 6.93214169e+01, -2.97741372e+00, -8.07475208e-01, ...,
#         -6.15140878e-02, -4.86716924e-02, -6.92653765e-02],
#        [ 7.86335479e+01, -1.51333216e+00, -1.09259725e-01, ...,
#         -4.88736702e-02, -1.28916280e-01,  5.53051265e-02],
#        ...,
#        [ 7.90137430e+01, -6.12506336e-01, -1.27343442e-01, ...,
#         -5.38158095e-02,  4.25567156e-01, -1.14167111e-01],
#        [ 7.29681475e+01, -4.64923839e+00,  7.18356832e-01, ...,
#          6.64198638e-02,  4.28522238e-02, -1.52673123e-01],
#        [ 7.63881860e+01, -1.65619874e+00, -4.76758297e-02, ...,
#         -5.65258579e-01,  5.79961073e-01,  4.01367172e-01]])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity(tinder_profiles_matrix)
# Out:
# array([[1.        , 0.99646088, 0.99817833, ..., 0.99837779, 0.99494244,
#         0.99785025],
#        [0.99646088, 1.        , 0.99942894, ..., 0.99879413, 0.9992087 ,
#         0.99895397],
#        [0.99817833, 0.99942894, 1.        , ..., 0.99954423, 0.99882141,
#         0.99949278],
#        ...,
#        [0.99837779, 0.99879413, 0.99954423, ..., 1.        , 0.99799746,
#         0.99916644],
#        [0.99494244, 0.9992087 , 0.99882141, ..., 0.99799746, 1.        ,
#         0.99837501],
#        [0.99785025, 0.99895397, 0.99949278, ..., 0.99916644, 0.99837501,
#         1.        ]])

# %%
# data for testing - for now just take a random sample

sample = tinder_data.sample(5)
sample
# Out:
#                       age  sex  height  education_level  dropped_out  \
# user_id
# fffe330037003000       21    0    72.0              3.0            0
# fffe340030003500       27    1    75.0              3.0            0
# fffe3100300034003400   30    1    70.0              5.0            0
# fffe3100330039003400   34    1    67.0              3.0            0
# fffe330032003000       26    0    64.0              3.0            0
#
#                       drinks_desperately  drinks_not at all  drinks_often  \
# user_id
# fffe330037003000                   False              False         False
# fffe340030003500                   False              False         False
# fffe3100300034003400               False              False         False
# fffe3100330039003400               False              False         False
# fffe330032003000                   False              False         False
#
#                       drinks_rarely  drinks_socially  ...  \
# user_id                                               ...
# fffe330037003000              False             True  ...
# fffe340030003500              False             True  ...
# fffe3100300034003400          False             True  ...
# fffe3100330039003400          False             True  ...
# fffe330032003000              False             True  ...
#
#                       body_profile_overweight  body_profile_rather not say  \
# user_id
# fffe330037003000                        False                        False
# fffe340030003500                        False                        False
# fffe3100300034003400                    False                        False
# fffe3100330039003400                    False                        False
# fffe330032003000                        False                        False
#
#                       body_profile_skinny  body_profile_thin  \
# user_id
# fffe330037003000                    False              False
# fffe340030003500                    False              False
# fffe3100300034003400                False              False
# fffe3100330039003400                False              False
# fffe330032003000                    False              False
#
#                       body_profile_used up  new_languages_interested  \
# user_id
# fffe330037003000                     False                      True
# fffe340030003500                     False                      True
# fffe3100300034003400                 False                     False
# fffe3100330039003400                 False                     False
# fffe330032003000                     False                      True
#
#                       new_languages_not interested  \
# user_id
# fffe330037003000                             False
# fffe340030003500                             False
# fffe3100300034003400                          True
# fffe3100330039003400                          True
# fffe330032003000                             False
#
#                       new_languages_somewhat interested  likes_dog  likes_cats
# user_id
# fffe330037003000                                  False          1           0
# fffe340030003500                                  False          1           0
# fffe3100300034003400                              False          1           0
# fffe3100330039003400                              False          0           0
# fffe330032003000                                  False          1           0
#
# [5 rows x 57 columns]

# %%
from sklearn.decomposition import TruncatedSVD 
from sklearn.metrics.pairwise import cosine_similarity

def get_recommendations(test_user_profile,
                        tinder_data, 
                        number_recommendations=20):

    # get the gender of the user
    test_profile_gender = list(test_profile.sex)[0]

    if test_profile_gender == 1:
        gender_preference = 0
    else:
        gender_preference = 1
    
    # get the tinder data of the opposite 
    td = tinder_data[tinder_data.sex == gender_preference]
    
    # Apply SVD to the training data
    svd = TruncatedSVD(n_components=20) 
    # this is a matrix of all the profiles of the opposite gender
    tinder_profiles_matrix = svd.fit_transform(td) 
    
    # we want to find profiles that are similar to the user
    # first we apply SVD
    test_profile_matrix = svd.transform(test_user_profile) 
    # then calculate the cosine similarity between the user's profile and all other profiles of the opposite gender
    cosine_sim_new = cosine_similarity(test_profile_matrix, tinder_profiles_matrix)

    # convert the scores and select the top N
    scores = pd.DataFrame(cosine_sim_new.transpose())
    scores_ordered = scores.sort_values(by=[0], ascending=False)

    # get the index for top n
    users_index = list(scores_ordered.head(number_recommendations).index)

    # get the user names of the top 
    tinder_data_manipulated = td.reset_index()
    user_ids = list(tinder_data_manipulated[tinder_data_manipulated.index.isin(users_index)].user_id)

    return user_ids

# %%
test_profile = pd.DataFrame(sample.iloc[0]).transpose()
test_profile
# Out:
#                  age sex height education_level dropped_out  \
# fffe330037003000  21   0   72.0             3.0           0
#
#                  drinks_desperately drinks_not at all drinks_often  \
# fffe330037003000              False             False        False
#
#                  drinks_rarely drinks_socially  ... body_profile_overweight  \
# fffe330037003000         False            True  ...                   False
#
#                  body_profile_rather not say body_profile_skinny  \
# fffe330037003000                       False               False
#
#                  body_profile_thin body_profile_used up  \
# fffe330037003000             False                False
#
#                  new_languages_interested new_languages_not interested  \
# fffe330037003000                     True                        False
#
#                  new_languages_somewhat interested likes_dog likes_cats
# fffe330037003000                             False         1          0
#
# [1 rows x 57 columns]

# %%
user_ids = get_recommendations(test_profile, tinder_data)
user_ids
# Out:
# ['fffe310030003900',
#  'fffe310038003600',
#  'fffe340031003700',
#  'fffe340031003900',
#  'fffe340032003300',
#  'fffe350034003800',
#  'fffe350035003500',
#  'fffe380033003500',
#  'fffe380036003100',
#  'fffe380036003300',
#  'fffe390031003400',
#  'fffe3100300031003100',
#  'fffe3100300035003800',
#  'fffe3100310031003900',
#  'fffe3100320032003400',
#  'fffe3100330030003100',
#  'fffe3100330035003600',
#  'fffe3100330038003600',
#  'fffe3100340039003000',
#  'fffe3100380036003800']

# %%
# read the raw data and get the profiles for the test user:

tinder_data_raw = pd.read_csv("../../03Lecture/data/tinder_data.csv")

tinder_data_raw[tinder_data_raw.user_id.isin(user_ids)]
# Out:
#                    user_id          username  age  status sex orientation  \
# 108       fffe310030003900  William Charette   22  single   m    straight
# 185       fffe310038003600       Donald Leon   20  single   m    straight
# 416       fffe340031003700     Cory Campbell   22  single   m    straight
# 418       fffe340031003900      Terence Paul   21  single   m    straight
# 422       fffe340032003300      Carl Sanchez   20  single   m    straight
# 547       fffe350034003800    Jeremy Thaniel   21  single   m    straight
# 554       fffe350035003500       James Rains   23  single   m    straight
# 834       fffe380033003500    Robert Jacquez   22  single   m    straight
# 860       fffe380036003100      Ryan Burnett   21  single   m    straight
# 862       fffe380036003300      Jesse Little   21  single   m    straight
# 913       fffe390031003400         John Ramp   22  single   m    straight
# 1010  fffe3100300031003100   Leonard Browder   21  single   m    straight
# 1057  fffe3100300035003800   Michael Lechner   22  single   m    straight
# 1118  fffe3100310031003900      Willie Roach   22  single   m    straight
# 1223  fffe3100320032003400       Brian Davis   21  single   m    straight
# 1300  fffe3100330030003100      Andrew Tully   21  single   m    straight
# 1355  fffe3100330035003600      Bryan Felmet   22  single   m    straight
# 1385  fffe3100330038003600       Raul Mcdade   21  single   m    straight
# 1489  fffe3100340039003000       Andrew Kane   21  single   m    straight
# 1867  fffe3100380036003800      Robert Lewis   22  single   m    straight
#
#         drinks      drugs  height                                job  \
# 108   socially  sometimes    70.0                  medicine / health
# 185   socially  sometimes    70.0       construction / craftsmanship
# 416   socially  sometimes    72.0  banking / financial / real estate
# 418   socially  sometimes    72.0        sales / marketing / biz dev
# 422   socially  sometimes    71.0                            student
# 547   socially  sometimes    75.0                            student
# 554   socially  sometimes    75.0               education / academia
# 834   socially      never    71.0        sales / marketing / biz dev
# 860   socially  sometimes    70.0                            student
# 862   socially      never    70.0                            student
# 913   socially      never    73.0               education / academia
# 1010  socially      never    72.0                            student
# 1057  socially  sometimes    72.0     computer / hardware / software
# 1118  socially  sometimes    73.0                              other
# 1223  socially      never    70.0                  medicine / health
# 1300  socially  sometimes    70.0        artistic / musical / writer
# 1355  socially  sometimes    72.0        artistic / musical / writer
# 1385  socially  sometimes    70.0                              other
# 1489  socially  sometimes    70.0                              other
# 1867  socially      never    74.0  banking / financial / real estate
#
#                        location                          pets     smokes  \
# 108   san francisco, california                    likes dogs         no
# 185        berkeley, california     likes dogs and likes cats         no
# 416        berkeley, california  likes dogs and dislikes cats         no
# 418      emeryville, california  likes dogs and dislikes cats  sometimes
# 422        berkeley, california       likes dogs and has cats         no
# 547          moraga, california     likes dogs and likes cats  sometimes
# 554   mountain view, california     likes dogs and likes cats         no
# 834   san francisco, california       likes dogs and has cats         no
# 860      menlo park, california       likes dogs and has cats         no
# 862        berkeley, california                    likes dogs         no
# 913        berkeley, california                    likes dogs         no
# 1010   walnut creek, california     likes dogs and likes cats         no
# 1057        benicia, california       likes dogs and has cats         no
# 1118        fairfax, california     likes dogs and likes cats         no
# 1223        oakland, california     likes dogs and likes cats         no
# 1300       berkeley, california       likes dogs and has cats         no
# 1355  san francisco, california       has dogs and likes cats         no
# 1385  san francisco, california                    likes dogs         no
# 1489       berkeley, california     likes dogs and likes cats        yes
# 1867     san rafael, california     likes dogs and likes cats         no
#
#                                                language        new_languages  \
# 108              english (fluently), russian (fluently)       not interested
# 185                                  english (fluently)       not interested
# 416   english (fluently), spanish (poorly), other (o...           interested
# 418                english (fluently), spanish (poorly)           interested
# 422   english (fluently), italian (fluently), arabic...           interested
# 547                english (fluently), spanish (poorly)           interested
# 554          english, german (fluently), spanish (okay)  somewhat interested
# 834   english (fluently), c++ (okay), japanese (poorly)           interested
# 860   english (fluently), spanish (poorly), russian ...           interested
# 862                english (fluently), chinese (poorly)           interested
# 913                                             english       not interested
# 1010                                   english (poorly)           interested
# 1057               english (fluently), spanish (poorly)           interested
# 1118                            english, spanish (okay)  somewhat interested
# 1223  english (poorly), gujarati (fluently), ancient...           interested
# 1300                english (fluently), french (poorly)           interested
# 1355             english (fluently), spanish (fluently)       not interested
# 1385                                 english (fluently)       not interested
# 1489                english (fluently), french (poorly)           interested
# 1867  english (fluently), farsi (fluently), spanish ...           interested
#
#         body_profile  education_level dropped_out  \
# 108         athletic              3.0          no
# 185             thin              3.0          no
# 416         athletic              2.0          no
# 418         athletic              2.0          no
# 422          average              2.0          no
# 547          average              4.0          no
# 554              fit              3.0          no
# 834           skinny              2.0          no
# 860             thin              2.0          no
# 862         athletic              2.0          no
# 913          average              3.0          no
# 1010         average              2.0          no
# 1057  a little extra              2.0          no
# 1118          skinny              2.0          no
# 1223        athletic              4.0          no
# 1300         average              2.0          no
# 1355        athletic              3.0          no
# 1385         average              2.0          no
# 1489         average              2.0          no
# 1867             fit              3.0          no
#
#                                                     bio location_preference
# 108   to be honest i don't like this summary thing b...           same city
# 185   my name is alex i would describe myself as you...           same city
# 416   hit me up if you wanna get to know a chill, do...           same city
# 418   my name is rodney. 20 years old, born and rais...            anywhere
# 422   i am a student. i spend my time playing in ban...           same city
# 547                                           i'm hope.           same city
# 554   i'm big-hearted, fun-loving, and upbeat. i'm o...           same city
# 834   man, you never realize how hard these things a...          same state
# 860   i'm a cool dude. i like some things-- i don't ...           same city
# 862   hi,  i go to school at uc berkeley. i am a fun...          same state
# 913   hmmm... well i'm pretty chill and i like to he...          same state
# 1010  i'm just a guy that loves art, video games, an...           same city
# 1057  hmmm, to summarize myself... i am laid back an...          same state
# 1118                                               bwah          same state
# 1223  well my name's ray, if you didn't figure that ...           same city
# 1300  well hmmm, my life currently revolves around m...           same city
# 1355  i decided to do this one 'key words' style:  2...            anywhere
# 1385  me? i'm winging it. i'm just a dude to be comp...          same state
# 1489  hey there. my name is jake, i'm a really easy-...           same city
# 1867  sociable, honest, and very straightforward. i'...           same city

# %%
# apply any known personal preference of the user

# %%
# what do we think about the recommendations?

# %%
# try for another user
test_profile = pd.DataFrame(sample.iloc[3]).transpose()
print(test_profile)
user_ids = get_recommendations(test_profile, tinder_data)
# Out:
#                      age sex height education_level dropped_out  \
# fffe3100300035003300  29   0   60.0             4.0           0
#
#                      drinks_desperately drinks_not at all drinks_often  \
# fffe3100300035003300              False             False        False
#
#                      drinks_rarely drinks_socially  ...  \
# fffe3100300035003300         False            True  ...
#
#                      body_profile_overweight body_profile_rather not say  \
# fffe3100300035003300                   False                       False
#
#                      body_profile_skinny body_profile_thin  \
# fffe3100300035003300               False             False
#
#                      body_profile_used up new_languages_interested  \
# fffe3100300035003300                False                    False
#
#                      new_languages_not interested  \
# fffe3100300035003300                        False
#
#                      new_languages_somewhat interested likes_dog likes_cats
# fffe3100300035003300                              True         1          0
#
# [1 rows x 57 columns]

# %%
tinder_data_raw[tinder_data_raw.user_id.isin(user_ids)]
# Out:
#                    user_id            username  age  status sex orientation  \
# 248       fffe320034003900          Ralph Boyd   34  single   m    straight
# 290       fffe320039003100        Fidel Tassin   34  single   m    straight
# 396       fffe330039003700     Demarcus Kinkel   34  single   m    straight
# 448       fffe340034003900    Freddie Lefebvre   35  single   m    straight
# 546       fffe350034003700       Frank Spooner   33  single   m    straight
# 787       fffe370038003800           Dion Zito   32  single   m    straight
# 840       fffe380034003100     William Zenisek   35  single   m    straight
# 864       fffe380036003500      Raymond Demski   35  single   m    straight
# 904       fffe390030003500       Rodney Church   33  single   m    straight
# 1095  fffe3100300039003600          John Moore   31  single   m    straight
# 1106  fffe3100310030003700           Harry Lee   31  single   m    straight
# 1294  fffe3100320039003500       James Sanchez   32  single   m    straight
# 1335  fffe3100330033003600         Jose Garcia   33  single   m    straight
# 1336  fffe3100330033003700            Jack Eby   32  single   m    straight
# 1348  fffe3100330034003900       Jose Trammell   34  single   m    straight
# 1493  fffe3100340039003400        Edward Craft   31  single   m    straight
# 1541  fffe3100350034003200  Dean Hollingsworth   34  single   m    straight
# 1635  fffe3100360033003600        Walter Logan   31  single   m    straight
# 1875  fffe3100380037003600          James Amos   33  single   m    straight
# 1950  fffe3100390035003100      Antonio Gonyea   33  single   m    straight
#
#           drinks  drugs  height                                job  \
# 248     socially  never    69.0             executive / management
# 290     socially  never    68.0  banking / financial / real estate
# 396       rarely  never    69.0             executive / management
# 448     socially  never    73.0       science / tech / engineering
# 546     socially  never    70.0                  medicine / health
# 787     socially  never    66.0               hospitality / travel
# 840     socially  never    74.0     computer / hardware / software
# 864     socially  never    73.0               hospitality / travel
# 904     socially  never    72.0       science / tech / engineering
# 1095    socially  never    66.0               law / legal services
# 1106    socially  never    65.0       science / tech / engineering
# 1294       often  never    65.0             executive / management
# 1335    socially  never    68.0               education / academia
# 1336    socially  never    69.0     computer / hardware / software
# 1348    socially  never    69.0                  medicine / health
# 1493    socially  never    67.0  banking / financial / real estate
# 1541    socially  never    68.0             executive / management
# 1635    socially  never    67.0  banking / financial / real estate
# 1875  not at all  never    68.0  banking / financial / real estate
# 1950    socially  never    70.0        sales / marketing / biz dev
#
#                        location                          pets smokes  \
# 248   mountain view, california                    likes dogs     no
# 290   san francisco, california                    likes dogs     no
# 396       san bruno, california     likes dogs and likes cats     no
# 448       palo alto, california                    likes dogs     no
# 546        berkeley, california                    likes dogs     no
# 787   san francisco, california     likes dogs and likes cats     no
# 840   san francisco, california     likes dogs and likes cats     no
# 864      burlingame, california                    likes dogs     no
# 904   san francisco, california     likes dogs and likes cats     no
# 1095  san francisco, california                    likes dogs     no
# 1106     menlo park, california     likes dogs and likes cats     no
# 1294  san francisco, california                    likes dogs     no
# 1335  san francisco, california     likes dogs and likes cats     no
# 1336  san francisco, california                    likes dogs     no
# 1348     emeryville, california  likes dogs and dislikes cats     no
# 1493  san francisco, california                      has dogs     no
# 1541     el cerrito, california     likes dogs and likes cats     no
# 1635      san mateo, california                    likes dogs     no
# 1875    san leandro, california                    likes dogs     no
# 1950  san francisco, california     likes dogs and likes cats     no
#
#                                                language        new_languages  \
# 248                                             english       not interested
# 290   english (fluently), spanish (fluently), chines...  somewhat interested
# 396   english (fluently), french (fluently), urdu (f...  somewhat interested
# 448   english (fluently), french (poorly), german (p...           interested
# 546   english, spanish (okay), french (poorly), swah...           interested
# 787   english (okay), english (okay), vietnamese (fl...  somewhat interested
# 840                 english (fluently), french (poorly)           interested
# 864                                             english       not interested
# 904   english (fluently), french (okay), spanish (okay)  somewhat interested
# 1095                                            english       not interested
# 1106  english (fluently), portuguese (fluently), hin...  somewhat interested
# 1294  english (fluently), spanish (fluently), hindi ...           interested
# 1335                     english (fluently), c++ (okay)  somewhat interested
# 1336               english (fluently), hindi (fluently)       not interested
# 1348                                   english, spanish       not interested
# 1493                           english, spanish, hebrew       not interested
# 1541                                            english       not interested
# 1635               english (fluently), chinese (poorly)           interested
# 1875                 english (fluently), chinese (okay)  somewhat interested
# 1950                                            english       not interested
#
#         body_profile  education_level dropped_out  \
# 248         athletic              3.0          no
# 290         athletic              3.0          no
# 396         athletic              4.0          no
# 448   a little extra              5.0          no
# 546         athletic              4.0          no
# 787          average              3.0          no
# 840         athletic              4.0          no
# 864         athletic              3.0          no
# 904         athletic              4.0          no
# 1095         average              4.0          no
# 1106             fit              4.0          no
# 1294        athletic              4.0          no
# 1335  a little extra              4.0          no
# 1336        athletic              5.0          no
# 1348        athletic              4.0          no
# 1493        athletic              4.0          no
# 1541        athletic              4.0          no
# 1635        athletic              4.0          no
# 1875         average              4.0          no
# 1950        athletic              4.0         yes
#
#                                                     bio location_preference
# 248             new to this site, just checking it out!           same city
# 290   i'm as american as you can get without actuall...           same city
# 396   i love to try new things and i really love to ...           same city
# 448   cities i have called home, from 2005 on: genev...           same city
# 546   berkeley man kisses boring online dating goodb...          same state
# 787           i am a bit quiet ,honest and hardworking.           same city
# 840   i'm a lifelong east coaster somehow loving sf....          same state
# 864   i'm a fun, kind, healthy person who loves to t...           same city
# 904   i like fascinating, passionate, creative peopl...           same city
# 1095  i've been living in san francisco since making...           same city
# 1106  i heart the letter s (silly, serious, sunny, s...           same city
# 1294  moved to the bay area a couple of years ago af...          same state
# 1335  i'm a san francisco native. i'm a classically ...           same city
# 1336  i moved to sf from dc two years ago. it's been...            anywhere
# 1348  not perfect by any means, but first word that ...          same state
# 1493  i love to be outside: running on trails, looki...           same city
# 1541  i smile a lot. not because i'm crazy, but beca...           same city
# 1635  when i was a kid, i spent hours and hours prac...           same city
# 1875  so i've never really been good at describing m...           same city
# 1950  i'm a strange mix of things. i think a lot and...           same city
